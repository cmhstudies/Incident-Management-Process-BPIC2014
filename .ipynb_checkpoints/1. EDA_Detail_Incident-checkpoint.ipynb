# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt
from pandas_profiling import ProfileReport
from pathlib import Path

# %%
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
# pd.set_option('display.width', None)

# %%
df = pd.read_csv("Detail_Incident.csv", sep=";", decimal=',')

# %%
df.dtypes
# Out:
# CI Name (aff)                   object
# CI Type (aff)                   object
# CI Subtype (aff)                object
# Service Component WBS (aff)     object
# Incident ID                     object
# Status                          object
# Impact                         float64
# Urgency                         object
# Priority                       float64
# Category                        object
# KM number                       object
# Alert Status                    object
# # Reassignments                float64
# Open Time                       object
# Reopen Time                     object
# Resolved Time                   object
# Close Time                      object
# Handle Time (Hours)            float64
# Closure Code                    object
# # Related Interactions         float64
# Related Interaction             object
# # Related Incidents            float64
# # Related Changes              float64
# Related Change                  object
# CI Name (CBy)                   object
# CI Type (CBy)                   object
# CI Subtype (CBy)                object
# ServiceComp WBS (CBy)           object
# Unnamed: 28                    float64
# Unnamed: 29                    float64
# Unnamed: 30                    float64
# Unnamed: 31                    float64
# Unnamed: 32                    float64
# Unnamed: 33                    float64
# Unnamed: 34                    float64
# Unnamed: 35                    float64
# Unnamed: 36                    float64
# Unnamed: 37                    float64
# Unnamed: 38                    float64
# Unnamed: 39                    float64
# Unnamed: 40                    float64
# Unnamed: 41                    float64
# Unnamed: 42                    float64
# Unnamed: 43                    float64
# Unnamed: 44                    float64
# Unnamed: 45                    float64
# Unnamed: 46                    float64
# Unnamed: 47                    float64
# Unnamed: 48                    float64
# Unnamed: 49                    float64
# Unnamed: 50                    float64
# Unnamed: 51                    float64
# Unnamed: 52                    float64
# Unnamed: 53                    float64
# Unnamed: 54                    float64
# Unnamed: 55                    float64
# Unnamed: 56                    float64
# Unnamed: 57                    float64
# Unnamed: 58                    float64
# Unnamed: 59                    float64
# Unnamed: 60                    float64
# Unnamed: 61                    float64
# Unnamed: 62                    float64
# Unnamed: 63                    float64
# Unnamed: 64                    float64
# Unnamed: 65                    float64
# Unnamed: 66                    float64
# Unnamed: 67                    float64
# Unnamed: 68                    float64
# Unnamed: 69                    float64
# Unnamed: 70                    float64
# Unnamed: 71                    float64
# Unnamed: 72                    float64
# Unnamed: 73                    float64
# Unnamed: 74                    float64
# Unnamed: 75                    float64
# Unnamed: 76                    float64
# Unnamed: 77                    float64
# dtype: object

# %%
df.columns
# Out:
# Index(['CI Name (aff)', 'CI Type (aff)', 'CI Subtype (aff)',
#        'Service Component WBS (aff)', 'Incident ID', 'Status', 'Impact',
#        'Urgency', 'Priority', 'Category', 'KM number', 'Alert Status',
#        '# Reassignments', 'Open Time', 'Reopen Time', 'Resolved Time',
#        'Close Time', 'Handle Time (Hours)', 'Closure Code',
#        '# Related Interactions', 'Related Interaction', '# Related Incidents',
#        '# Related Changes', 'Related Change', 'CI Name (CBy)', 'CI Type (CBy)',
#        'CI Subtype (CBy)', 'ServiceComp WBS (CBy)', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
#        'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40',
#        'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44',
#        'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48',
#        'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52',
#        'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56',
#        'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59', 'Unnamed: 60',
#        'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63', 'Unnamed: 64',
#        'Unnamed: 65', 'Unnamed: 66', 'Unnamed: 67', 'Unnamed: 68',
#        'Unnamed: 69', 'Unnamed: 70', 'Unnamed: 71', 'Unnamed: 72',
#        'Unnamed: 73', 'Unnamed: 74', 'Unnamed: 75', 'Unnamed: 76',
#        'Unnamed: 77'],
#       dtype='object')

# %%
df.dropna(axis='columns', how='all', inplace=True)

# %%
df.shape
# Out:
# (46809, 28)

# %%
df.dropna(axis='rows', how='all', inplace=True)

# %%
df.shape
# Out:
# (46606, 28)

# %%
df.columns = df.columns.str.replace(' ', '_')
df.columns = df.columns.str.replace('(', '')
df.columns = df.columns.str.replace(')', '')
df.columns = df.columns.str.replace('#', 'Count')

# %%
df.columns
# Out:
# Index(['CI_Name_aff', 'CI_Type_aff', 'CI_Subtype_aff',
#        'Service_Component_WBS_aff', 'Incident_ID', 'Status', 'Impact',
#        'Urgency', 'Priority', 'Category', 'KM_number', 'Alert_Status',
#        'Count_Reassignments', 'Open_Time', 'Reopen_Time', 'Resolved_Time',
#        'Close_Time', 'Handle_Time_Hours', 'Closure_Code',
#        'Count_Related_Interactions', 'Related_Interaction',
#        'Count_Related_Incidents', 'Count_Related_Changes', 'Related_Change',
#        'CI_Name_CBy', 'CI_Type_CBy', 'CI_Subtype_CBy', 'ServiceComp_WBS_CBy'],
#       dtype='object')

# %%
df.tail()
# Out:
#       CI_Name_aff  CI_Type_aff            CI_Subtype_aff  \
# 46601   SBA000464  application  Server Based Application
# 46602   SBA000461  application  Server Based Application
# 46603   LAP000019     computer                    Laptop
# 46604   WBA000058  application     Web Based Application
# 46605   DCE000077     hardware       DataCenterEquipment
#
#       Service_Component_WBS_aff Incident_ID  Status  Impact Urgency  Priority  \
# 46601                 WBS000073   IM0047053  Closed     4.0       4       4.0
# 46602                 WBS000073   IM0047054  Closed     4.0       4       4.0
# 46603                 WBS000091   IM0047055  Closed     5.0       5       5.0
# 46604                 WBS000073   IM0047056  Closed     4.0       4       4.0
# 46605                 WBS000267   IM0047057  Closed     3.0       3       3.0
#
#        Category  KM_number Alert_Status  Count_Reassignments  \
# 46601  incident  KM0001314       closed                  0.0
# 46602  incident  KM0002360       closed                  0.0
# 46603  incident  KM0000315       closed                  0.0
# 46604  incident  KM0001287       closed                  0.0
# 46605  incident  KM0000182       closed                  0.0
#
#                  Open_Time Reopen_Time        Resolved_Time  \
# 46601  31/03/2014 16:23:42         NaN  31/03/2014 16:29:21
# 46602  31/03/2014 15:03:45         NaN  31/03/2014 15:29:19
# 46603  31/03/2014 15:28:22         NaN  31/03/2014 15:32:37
# 46604  31/03/2014 15:35:35         NaN  31/03/2014 15:42:34
# 46605  31/03/2014 17:24:49         NaN  31/03/2014 22:47:29
#
#                 Close_Time  Handle_Time_Hours Closure_Code  \
# 46601  31/03/2014 16:29:24           0.095000        Other
# 46602  31/03/2014 15:29:27           0.428333   User error
# 46603  31/03/2014 15:32:40           0.071667     Hardware
# 46604  31/03/2014 15:42:36           0.116944     Software
# 46605  31/03/2014 22:47:32           0.586389     Hardware
#
#        Count_Related_Interactions Related_Interaction  \
# 46601                         1.0           SD0147021
# 46602                         1.0           SD0146967
# 46603                         1.0           SD0146982
# 46604                         1.0           SD0146986
# 46605                         1.0           SD0147088
#
#        Count_Related_Incidents  Count_Related_Changes Related_Change  \
# 46601                      NaN                    NaN            NaN
# 46602                      NaN                    NaN            NaN
# 46603                      NaN                    NaN            NaN
# 46604                      NaN                    NaN            NaN
# 46605                      NaN                    NaN            NaN
#
#       CI_Name_CBy  CI_Type_CBy            CI_Subtype_CBy ServiceComp_WBS_CBy
# 46601   SBA000464  application  Server Based Application           WBS000073
# 46602   SBA000461  application  Server Based Application           WBS000073
# 46603   LAP000019     computer                    Laptop           WBS000091
# 46604   WBA000058  application     Web Based Application           WBS000073
# 46605   DCE000077     hardware       DataCenterEquipment           WBS000267

# %%
df.Urgency.value_counts()
# Out:
# 4               18349
# 5               14094
# 3                5362
# 4                4239
# 5                2685
# 3                1174
# 2                 607
# 2                  89
# 1                   4
# 1                   2
# 5 - Very Low        1
# Name: Urgency, dtype: int64

# %%
sns.countplot(x='Urgency', data=df)

# %%
colsDatetime = ['Open_Time', 'Reopen_Time', 'Resolved_Time', 'Close_Time']

# %%
for i in colsDatetime:
    df[i] = pd.to_datetime(df[i], format='%d/%m/%Y %H:%M:%S', errors='coerce' )

# %%
df.dtypes
# Out:
# CI_Name_aff                           object
# CI_Type_aff                           object
# CI_Subtype_aff                        object
# Service_Component_WBS_aff             object
# Incident_ID                           object
# Status                                object
# Impact                               float64
# Urgency                               object
# Priority                             float64
# Category                              object
# KM_number                             object
# Alert_Status                          object
# Count_Reassignments                  float64
# Open_Time                     datetime64[ns]
# Reopen_Time                   datetime64[ns]
# Resolved_Time                 datetime64[ns]
# Close_Time                    datetime64[ns]
# Handle_Time_Hours                    float64
# Closure_Code                          object
# Count_Related_Interactions           float64
# Related_Interaction                   object
# Count_Related_Incidents              float64
# Count_Related_Changes                float64
# Related_Change                        object
# CI_Name_CBy                           object
# CI_Type_CBy                           object
# CI_Subtype_CBy                        object
# ServiceComp_WBS_CBy                   object
# dtype: object

# %%
df.head(30)
# Out:
#    CI_Name_aff     CI_Type_aff            CI_Subtype_aff  \
# 0    SUB000508  subapplication     Web Based Application
# 1    WBA000124     application     Web Based Application
# 2    DTA000024     application       Desktop Application
# 3    WBA000124     application     Web Based Application
# 4    WBA000124     application     Web Based Application
# 5    WBA000124     application     Web Based Application
# 6    WBA000082     application     Web Based Application
# 7    WBA000124     application     Web Based Application
# 8    WBA000124     application     Web Based Application
# 9    WBA000082     application     Web Based Application
# 10   WBA000124     application     Web Based Application
# 11   WBA000124     application     Web Based Application
# 12   WBA000082     application     Web Based Application
# 13   WBA000124     application     Web Based Application
# 14   SBA000698     application  Server Based Application
# 15   WBA000082     application     Web Based Application
# 16   SUB000539  subapplication     Web Based Application
# 17   SUB000535  subapplication     Web Based Application
# 18   DTA000616     application       Desktop Application
# 19   WBA000082     application     Web Based Application
# 20   WBA000124     application     Web Based Application
# 21   WBA000116     application     Web Based Application
# 22   WBA000124     application     Web Based Application
# 23   WBA000124     application     Web Based Application
# 24   SUB000535  subapplication     Web Based Application
# 25   SUB000535  subapplication     Web Based Application
# 26   WBA000082     application     Web Based Application
# 27   SBA000662     application  Server Based Application
# 28   SBA000607     application  Server Based Application
# 29   SBA000263     application  Server Based Application
#
#    Service_Component_WBS_aff Incident_ID  Status  Impact Urgency  Priority  \
# 0                  WBS000162   IM0000004  Closed     4.0       4       4.0
# 1                  WBS000088   IM0000005  Closed     3.0       3       3.0
# 2                  WBS000092   IM0000006  Closed     3.0       3       3.0
# 3                  WBS000088   IM0000011  Closed     4.0       4       4.0
# 4                  WBS000088   IM0000012  Closed     4.0       4       4.0
# 5                  WBS000088   IM0000013  Closed     4.0       4       4.0
# 6                  WBS000055   IM0000014  Closed     4.0       4       4.0
# 7                  WBS000088   IM0000015  Closed     4.0       4       4.0
# 8                  WBS000088   IM0000017  Closed     3.0       3       3.0
# 9                  WBS000055   IM0000018  Closed     4.0       4       4.0
# 10                 WBS000088   IM0000019  Closed     4.0       4       4.0
# 11                 WBS000088   IM0000020  Closed     4.0       4       4.0
# 12                 WBS000055   IM0000021  Closed     4.0       4       4.0
# 13                 WBS000088   IM0000022  Closed     4.0       4       4.0
# 14                 WBS000090   IM0000023  Closed     3.0       3       3.0
# 15                 WBS000055   IM0000024  Closed     4.0       4       4.0
# 16                 WBS000073   IM0000028  Closed     4.0       4       4.0
# 17                 WBS000066   IM0000031  Closed     4.0       4       4.0
# 18                 WBS000092   IM0000033  Closed     3.0       3       3.0
# 19                 WBS000055   IM0000034  Closed     5.0       5       5.0
# 20                 WBS000088   IM0000035  Closed     4.0       4       4.0
# 21                 WBS000066   IM0000038  Closed     4.0       4       4.0
# 22                 WBS000088   IM0000041  Closed     4.0       4       4.0
# 23                 WBS000088   IM0000042  Closed     4.0       4       4.0
# 24                 WBS000066   IM0000045  Closed     4.0       4       4.0
# 25                 WBS000066   IM0000046  Closed     4.0       4       4.0
# 26                 WBS000055   IM0000047  Closed     4.0       4       4.0
# 27                 WBS000071   IM0000048  Closed     5.0       5       5.0
# 28                 WBS000263   IM0000049  Closed     5.0       5       5.0
# 29                 WBS000072   IM0000053  Closed     5.0       5       5.0
#
#                    Category  KM_number Alert_Status  Count_Reassignments  \
# 0                  incident  KM0000553       closed                 26.0
# 1                  incident  KM0000611       closed                 33.0
# 2   request for information  KM0000339       closed                  3.0
# 3                  incident  KM0000611       closed                 13.0
# 4                  incident  KM0000611       closed                  2.0
# 5                  incident  KM0000611       closed                  4.0
# 6                  incident  KM0000401       closed                  2.0
# 7                  incident  KM0000611       closed                  5.0
# 8                  incident  KM0000611       closed                  2.0
# 9                  incident  KM0000401       closed                  2.0
# 10                 incident  KM0000611       closed                  6.0
# 11                 incident  KM0000611       closed                  8.0
# 12                 incident  KM0000401       closed                  5.0
# 13                 incident  KM0000611       closed                 17.0
# 14                 incident  KM0000670       closed                  1.0
# 15                 incident  KM0000401       closed                  3.0
# 16                 incident  KM0000852       closed                  1.0
# 17                 incident  KM0000928       closed                  7.0
# 18                 incident  KM0001430       closed                 17.0
# 19                 incident  KM0000401       closed                  5.0
# 20                 incident  KM0000611       closed                  6.0
# 21                 incident  KM0000579       closed                  4.0
# 22                 incident  KM0000611       closed                  2.0
# 23                 incident  KM0000611       closed                 12.0
# 24                 incident  KM0000928       closed                  7.0
# 25                 incident  KM0000931       closed                  3.0
# 26                 incident  KM0000401       closed                  4.0
# 27  request for information  KM0000524       closed                  0.0
# 28  request for information  KM0000592       closed                 11.0
# 29  request for information  KM0001104       closed                  2.0
#
#              Open_Time         Reopen_Time       Resolved_Time  \
# 0  2012-02-05 13:32:57                 NaT 2013-11-04 13:50:27
# 1  2012-03-12 15:44:24 2013-12-02 12:31:02 2013-12-02 12:36:21
# 2  2012-03-29 12:36:01                 NaT 2014-01-13 15:12:38
# 3  2012-07-17 11:49:00                 NaT 2013-11-14 09:31:09
# 4  2012-08-10 11:01:40                 NaT 2013-11-08 13:55:49
# 5  2012-08-10 11:27:59                 NaT 2013-11-08 13:54:07
# 6  2012-08-15 14:17:55                 NaT 2013-12-27 10:59:28
# 7  2012-08-22 16:31:42                 NaT 2013-11-08 14:09:05
# 8  2012-08-29 15:59:14                 NaT 2013-11-08 14:02:06
# 9  2012-09-03 16:04:05                 NaT 2013-11-08 14:33:43
# 10 2012-09-21 12:56:57                 NaT 2013-11-08 14:23:09
# 11 2012-10-01 10:49:49                 NaT 2013-11-08 14:18:14
# 12 2012-10-02 12:12:39 2014-01-28 14:07:43 2014-02-04 09:38:28
# 13 2012-10-15 15:50:52                 NaT                 NaT
# 14 2012-10-18 14:33:14                 NaT 2013-12-12 10:23:43
# 15 2012-10-23 12:01:00                 NaT 2013-11-08 14:57:45
# 16 2012-11-21 11:53:37                 NaT 2013-12-20 11:30:57
# 17 2012-12-05 15:17:24                 NaT 2013-10-30 08:45:11
# 18 2012-12-07 14:34:52                 NaT 2013-11-30 10:39:06
# 19 2012-12-10 14:44:09 2014-02-11 14:50:29 2014-03-28 14:20:27
# 20 2012-12-24 16:31:41                 NaT 2013-11-14 09:49:34
# 21 2013-01-15 15:36:32                 NaT 2014-01-29 15:01:08
# 22 2013-01-22 16:38:20                 NaT 2013-11-08 14:55:25
# 23 2013-01-23 14:39:32                 NaT 2013-11-08 15:21:36
# 24 2013-01-30 16:37:11                 NaT 2014-01-27 12:33:05
# 25 2013-01-31 17:27:21                 NaT 2014-02-12 09:05:44
# 26 2013-02-04 14:38:28                 NaT 2014-01-02 15:22:18
# 27 2013-02-06 14:07:43 2013-10-17 12:22:40 2013-10-17 14:00:26
# 28 2013-02-08 10:47:28                 NaT 2013-10-17 15:40:07
# 29 2013-02-18 11:59:54 2013-12-04 13:58:20                 NaT
#
#             Close_Time  Handle_Time_Hours                  Closure_Code  \
# 0  2013-11-04 13:51:17        3871.691111                         Other
# 1  2013-12-02 12:36:25        4354.786389                      Software
# 2  2014-01-13 15:13:11        4843.119444  No error - works as designed
# 3  2013-11-14 09:31:24          43.218333                Operator error
# 4  2013-11-08 13:55:52        3383.903333                         Other
# 5  2013-11-08 13:54:12        3383.436944                         Other
# 6  2013-12-27 10:59:32        3703.191389                       Unknown
# 7  2013-11-08 14:09:09        3294.624167                         Other
# 8  2013-11-08 14:02:20           0.862778                         Other
# 9  2013-11-08 14:35:42        3211.526944  No error - works as designed
# 10 2013-11-08 14:23:54        3067.449167                      Software
# 11 2013-11-08 14:22:05        1322.619167                      Software
# 12 2014-02-04 09:38:47        1132.428333                      Software
# 13 2013-11-14 13:33:35          66.754167                      Software
# 14 2013-12-12 10:24:43        3114.358056                          Data
# 15 2013-11-08 14:58:02        2837.950556                         Other
# 16 2013-12-20 11:31:08        1223.748333                         Other
# 17 2013-10-30 08:45:52          37.927778                       Unknown
# 18 2013-11-30 10:39:09        2626.733889                         Other
# 19 2014-03-28 14:20:30         931.780833                         Other
# 20 2013-11-14 09:49:58        1930.483333                      Referred
# 21 2014-01-29 15:01:15        2781.911944                      Software
# 22 2013-11-08 14:55:29        2150.785833                         Other
# 23 2013-11-08 15:22:18        2142.712778  No error - works as designed
# 24 2014-01-27 12:33:10        1118.525000                      Software
# 25 2014-02-12 09:05:52        2760.606389                         Other
# 26 2014-01-02 15:22:30        2447.233889                         Other
# 27 2013-10-17 14:00:29           3.885556  No error - works as designed
# 28 2013-10-17 15:40:23        1852.881944                         Other
# 29 2013-12-04 14:00:09          27.745556                         Other
#
#     Count_Related_Interactions Related_Interaction  Count_Related_Incidents  \
# 0                          1.0           SD0000007                      2.0
# 1                          1.0           SD0000011                      1.0
# 2                          1.0           SD0000017                      NaN
# 3                          1.0           SD0000025                      NaN
# 4                          1.0           SD0000029                      NaN
# 5                          1.0           SD0000031                      NaN
# 6                          1.0           SD0000033                      NaN
# 7                          1.0           SD0000034                      NaN
# 8                          1.0           SD0000036                      NaN
# 9                          1.0           SD0000037                      NaN
# 10                         1.0           SD0000040                      NaN
# 11                         1.0           SD0000042                      NaN
# 12                         2.0         #MULTIVALUE                      NaN
# 13                         1.0           SD0000043                      2.0
# 14                         1.0           SD0000045                      NaN
# 15                         1.0           SD0000046                      2.0
# 16                         1.0           SD0000053                      NaN
# 17                         1.0           SD0000055                      NaN
# 18                         2.0         #MULTIVALUE                      NaN
# 19                         2.0         #MULTIVALUE                      NaN
# 20                         1.0           SD0000058                      2.0
# 21                         1.0           SD0000063                      1.0
# 22                         1.0           SD0000065                      NaN
# 23                         1.0           SD0000068                      NaN
# 24                         1.0           SD0000072                      NaN
# 25                         1.0           SD0000073                      1.0
# 26                         1.0           SD0000074                      NaN
# 27                         2.0         #MULTIVALUE                      NaN
# 28                         1.0           SD0000076                      NaN
# 29                         2.0         #MULTIVALUE                      NaN
#
#     Count_Related_Changes Related_Change CI_Name_CBy     CI_Type_CBy  \
# 0                     NaN            NaN   SUB000508  subapplication
# 1                     NaN            NaN   WBA000124     application
# 2                     NaN            NaN   DTA000024     application
# 3                     NaN            NaN   WBA000124     application
# 4                     NaN            NaN   SUB000508  subapplication
# 5                     NaN            NaN   SUB000508  subapplication
# 6                     NaN            NaN   WBA000082     application
# 7                     NaN            NaN   WBA000124     application
# 8                     NaN            NaN        #N/B            #N/B
# 9                     NaN            NaN        #N/B            #N/B
# 10                    1.0      C00000056        #N/B            #N/B
# 11                    NaN            NaN        #N/B            #N/B
# 12                    NaN            NaN   WBA000082     application
# 13                    NaN            NaN   WBA000109     application
# 14                    NaN            NaN   HMD000012        hardware
# 15                    NaN            NaN        #N/B            #N/B
# 16                    NaN            NaN   SUB000539  subapplication
# 17                    NaN            NaN   SUB000508  subapplication
# 18                    NaN            NaN   DTA000616     application
# 19                    NaN            NaN   WBA000082     application
# 20                    NaN            NaN   WBA000109     application
# 21                    NaN            NaN   SUB000522  subapplication
# 22                    NaN            NaN   WBA000124     application
# 23                    NaN            NaN        #N/B            #N/B
# 24                    NaN            NaN   SUB000535  subapplication
# 25                    NaN            NaN   SUB000535  subapplication
# 26                    NaN            NaN   WBA000082     application
# 27                    NaN            NaN   WSR000394        computer
# 28                    NaN            NaN        #N/B            #N/B
# 29                    NaN            NaN   SBA000263     application
#
#               CI_Subtype_CBy ServiceComp_WBS_CBy
# 0      Web Based Application           WBS000162
# 1      Web Based Application           WBS000088
# 2        Desktop Application           WBS000092
# 3      Web Based Application           WBS000088
# 4      Web Based Application           WBS000162
# 5      Web Based Application           WBS000162
# 6      Web Based Application           WBS000055
# 7      Web Based Application           WBS000088
# 8                       #N/B                #N/B
# 9                       #N/B                #N/B
# 10                      #N/B                #N/B
# 11                      #N/B                #N/B
# 12     Web Based Application           WBS000055
# 13     Web Based Application           WBS000162
# 14             MigratieDummy                #N/B
# 15                      #N/B                #N/B
# 16     Web Based Application           WBS000073
# 17     Web Based Application           WBS000162
# 18       Desktop Application           WBS000092
# 19     Web Based Application           WBS000055
# 20     Web Based Application           WBS000162
# 21     Web Based Application           WBS000066
# 22     Web Based Application           WBS000088
# 23                      #N/B                #N/B
# 24     Web Based Application           WBS000066
# 25     Web Based Application           WBS000066
# 26     Web Based Application           WBS000055
# 27            Windows Server                #N/B
# 28                      #N/B                #N/B
# 29  Server Based Application           WBS000072

# %%
df.tail()
# Out:
#       CI_Name_aff  CI_Type_aff            CI_Subtype_aff  \
# 46601   SBA000464  application  Server Based Application
# 46602   SBA000461  application  Server Based Application
# 46603   LAP000019     computer                    Laptop
# 46604   WBA000058  application     Web Based Application
# 46605   DCE000077     hardware       DataCenterEquipment
#
#       Service_Component_WBS_aff Incident_ID  Status  Impact Urgency  Priority  \
# 46601                 WBS000073   IM0047053  Closed     4.0       4       4.0
# 46602                 WBS000073   IM0047054  Closed     4.0       4       4.0
# 46603                 WBS000091   IM0047055  Closed     5.0       5       5.0
# 46604                 WBS000073   IM0047056  Closed     4.0       4       4.0
# 46605                 WBS000267   IM0047057  Closed     3.0       3       3.0
#
#        Category  KM_number Alert_Status  Count_Reassignments  \
# 46601  incident  KM0001314       closed                  0.0
# 46602  incident  KM0002360       closed                  0.0
# 46603  incident  KM0000315       closed                  0.0
# 46604  incident  KM0001287       closed                  0.0
# 46605  incident  KM0000182       closed                  0.0
#
#                 Open_Time Reopen_Time       Resolved_Time          Close_Time  \
# 46601 2014-03-31 16:23:42         NaT 2014-03-31 16:29:21 2014-03-31 16:29:24
# 46602 2014-03-31 15:03:45         NaT 2014-03-31 15:29:19 2014-03-31 15:29:27
# 46603 2014-03-31 15:28:22         NaT 2014-03-31 15:32:37 2014-03-31 15:32:40
# 46604 2014-03-31 15:35:35         NaT 2014-03-31 15:42:34 2014-03-31 15:42:36
# 46605 2014-03-31 17:24:49         NaT 2014-03-31 22:47:29 2014-03-31 22:47:32
#
#        Handle_Time_Hours Closure_Code  Count_Related_Interactions  \
# 46601           0.095000        Other                         1.0
# 46602           0.428333   User error                         1.0
# 46603           0.071667     Hardware                         1.0
# 46604           0.116944     Software                         1.0
# 46605           0.586389     Hardware                         1.0
#
#       Related_Interaction  Count_Related_Incidents  Count_Related_Changes  \
# 46601           SD0147021                      NaN                    NaN
# 46602           SD0146967                      NaN                    NaN
# 46603           SD0146982                      NaN                    NaN
# 46604           SD0146986                      NaN                    NaN
# 46605           SD0147088                      NaN                    NaN
#
#       Related_Change CI_Name_CBy  CI_Type_CBy            CI_Subtype_CBy  \
# 46601            NaN   SBA000464  application  Server Based Application
# 46602            NaN   SBA000461  application  Server Based Application
# 46603            NaN   LAP000019     computer                    Laptop
# 46604            NaN   WBA000058  application     Web Based Application
# 46605            NaN   DCE000077     hardware       DataCenterEquipment
#
#       ServiceComp_WBS_CBy
# 46601           WBS000073
# 46602           WBS000073
# 46603           WBS000091
# 46604           WBS000073
# 46605           WBS000267

# %%
df.Impact = df.Impact.astype(str).str[:1]
df.Priority = df.Priority.astype(str).str[:1]
df.Urgency = df.Urgency.astype(str).str[:1]

# %%
df.Urgency.value_counts()
# Out:
# 4    22588
# 5    16780
# 3     6536
# 2      696
# 1        6
# Name: Urgency, dtype: int64

# %%
df.dtypes
# Out:
# CI_Name_aff                           object
# CI_Type_aff                           object
# CI_Subtype_aff                        object
# Service_Component_WBS_aff             object
# Incident_ID                           object
# Status                                object
# Impact                                object
# Urgency                               object
# Priority                              object
# Category                              object
# KM_number                             object
# Alert_Status                          object
# Count_Reassignments                  float64
# Open_Time                     datetime64[ns]
# Reopen_Time                   datetime64[ns]
# Resolved_Time                 datetime64[ns]
# Close_Time                    datetime64[ns]
# Handle_Time_Hours                    float64
# Closure_Code                          object
# Count_Related_Interactions           float64
# Related_Interaction                   object
# Count_Related_Incidents              float64
# Count_Related_Changes                float64
# Related_Change                        object
# CI_Name_CBy                           object
# CI_Type_CBy                           object
# CI_Subtype_CBy                        object
# ServiceComp_WBS_CBy                   object
# dtype: object

# %%
df[df['Status'] == "Work in progress"]
# Out:
#      CI_Name_aff CI_Type_aff  CI_Subtype_aff Service_Component_WBS_aff  \
# 3492   CBD000824    computer  Banking Device                 WBS000146
# 4254   CBD000863    computer  Banking Device                 WBS000146
# 4807   CBD000857    computer  Banking Device                 WBS000146
# 5868   CBD000399    computer  Banking Device                 WBS000146
# 6797   CBD000503    computer  Banking Device                 WBS000146
# 7479   CBD000308    computer  Banking Device                 WBS000146
# 7964   CBD000379    computer  Banking Device                 WBS000146
# 8315   CBD001200    computer  Banking Device                 WBS000146
# 8666   CBD001205    computer  Banking Device                 WBS000146
#
#      Incident_ID            Status Impact Urgency Priority  Category  \
# 3492   IM0003614  Work in progress      4       4        4  incident
# 4254   IM0004380  Work in progress      2       2        2  incident
# 4807   IM0004937  Work in progress      2       2        2  incident
# 5868   IM0006014  Work in progress      3       3        3  incident
# 6797   IM0006951  Work in progress      4       4        4  incident
# 7479   IM0007636  Work in progress      3       3        3  incident
# 7964   IM0008124  Work in progress      3       3        3  incident
# 8315   IM0008477  Work in progress      2       2        2  incident
# 8666   IM0008829  Work in progress      4       4        4  incident
#
#       KM_number Alert_Status  Count_Reassignments           Open_Time  \
# 3492  KM0000266       closed                  3.0 2013-10-08 13:10:12
# 4254  KM0000274       closed                  0.0 2013-10-10 11:48:00
# 4807  KM0000274       closed                  1.0 2013-10-14 11:24:22
# 5868  KM0000274       closed                  1.0 2013-10-16 13:04:20
# 6797  KM0000281       closed                  2.0 2013-10-21 12:38:54
# 7479  KM0000280       closed                  0.0 2013-10-23 12:10:35
# 7964  KM0000280       closed                  3.0 2013-10-24 14:31:14
# 8315  KM0000493       closed                  1.0 2013-10-28 10:08:53
# 8666  KM0000281       closed                  1.0 2013-10-28 15:03:18
#
#      Reopen_Time       Resolved_Time          Close_Time  Handle_Time_Hours  \
# 3492         NaT 2013-10-09 08:55:09 2013-10-09 08:55:21           6.252500
# 4254         NaT 2013-10-10 13:20:40 2013-10-10 13:20:45           1.545833
# 4807         NaT 2013-10-14 14:05:33 2013-10-14 14:05:36           2.687222
# 5868         NaT 2013-10-16 13:41:46 2013-10-16 13:41:50           0.625000
# 6797         NaT 2013-10-21 16:41:18 2013-10-21 16:42:27           4.059167
# 7479         NaT 2013-10-23 12:21:54 2013-10-23 12:21:57           0.189444
# 7964         NaT 2013-10-28 17:18:17 2013-10-28 17:18:20          23.785000
# 8315         NaT 2013-10-28 14:20:00 2013-10-28 14:20:03           4.185000
# 8666         NaT 2013-10-29 17:01:23 2013-10-29 17:01:26          12.468889
#
#      Closure_Code  Count_Related_Interactions Related_Interaction  \
# 3492     Hardware                         1.0           SD0008234
# 4254        Other                         1.0           SD0010529
# 4807        Other                         1.0           SD0012422
# 5868     Hardware                         1.0           SD0015040
# 6797      Unknown                         1.0           SD0018013
# 7479      Unknown                         1.0           SD0020154
# 7964        Other                         1.0           SD0021394
# 8315        Other                         1.0           SD0022980
# 8666     Hardware                         1.0           SD0023574
#
#       Count_Related_Incidents  Count_Related_Changes Related_Change  \
# 3492                      NaN                    NaN            NaN
# 4254                      NaN                    NaN            NaN
# 4807                      NaN                    NaN            NaN
# 5868                      NaN                    NaN            NaN
# 6797                      NaN                    NaN            NaN
# 7479                      NaN                    NaN            NaN
# 7964                      NaN                    NaN            NaN
# 8315                      NaN                    NaN            NaN
# 8666                      NaN                    NaN            NaN
#
#      CI_Name_CBy CI_Type_CBy  CI_Subtype_CBy ServiceComp_WBS_CBy
# 3492   CBD000824    computer  Banking Device           WBS000146
# 4254   CBD000863    computer  Banking Device           WBS000146
# 4807   CBD000857    computer  Banking Device           WBS000146
# 5868   CBD000399    computer  Banking Device           WBS000146
# 6797   CBD000503    computer  Banking Device           WBS000146
# 7479   CBD000308    computer  Banking Device           WBS000146
# 7964   CBD000379    computer  Banking Device           WBS000146
# 8315   CBD001200    computer  Banking Device           WBS000146
# 8666   CBD001205    computer  Banking Device           WBS000146

# %%
with open("1.a.Detail_Incident.csv",'w') as f:
    df.to_csv(f, index=False)

# %%
profile = ProfileReport(df, title="Profile of BPIC 2014 Detail_Incident Data after Initial Cleaning", html={'style': {'full_width': True}})

# %%
profile.to_file(Path(str("1.b.Detail_Incident_Profile.html")))
